# %%
# imgage trasnformation ---> transofr me images more especifict the training set to prevent overfitting
#Image Agmetation--> increase the # of images

# %%
import tensorflow as tf
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
def plot_images_from_dir(path):
    """ it takes a path and return the plot fo each image"""
    images_classes = []
    for cls in os.listdir(path): # get all the classes in for each folder
        if cls != '.DS_Store' and cls != '.ipynb_checkpoints': # remove .DS_Store and checkpoints
            images_classes.append(cls)
    for i in images_classes: # loop over each class
        new_images = []
        my_folder = os.path.join(path,i)
        for file in os.listdir(os.path.join(path,i)):
            if file != '.DS_Store' and file != '.ipynb_checkpoints':
                new_images.append(cv2.imread(os.path.join(my_folder,file))) # convert the path into an array
        plt.figure(figsize=(50,50))
        columns = 10
        for i, image in enumerate(new_images):
            plt.subplot(len(new_images) / columns + 1, columns, i + 1)
            plt.imshow(image)
            plt.show()

# %%
folder = "/Users/cristinamulas/Desktop/deep_learning_project/data/val/"

plot_images_from_dir(folder)

# %%
from keras.preprocessing.image import ImageDataGenerator
import os
os.getcwd()
# Out:
# Using TensorFlow backend.
# '/Users/cristinamulas/Desktop/deep_learning_project'

# %%
# it trnasfor the images: normalize and the trasnform it. Prevent overfitting
# train_datagen = ImageDataGenerator( rescale = 1. / 255, shear_range =0.2, zoom_range= 0.2, horizontal_flip = True)

# %%
# base_path = os.getcwd() # get the working direntory
# train_data_path = os.path.join(base_path + '/data/train') # add the new folder
# train_data_path

# test_data_path = os.path.join(base_path + '/data/test') # add the new folder
# test_data_path

# val_data_path = os.path.join(base_path + '/data/val') # add the new folder
# val_data_path
# Out:
# '/Users/cristinamulas/Desktop/deep_learning_project/data/val'

# %%
# class_model = binary or categorical
training_set = train_datagen.flow_from_directory(train_data_path, target_size = (64, 64), batch_size= 32, class_mode ='categorical')
# Out:
# Found 96 images belonging to 7 classes.

# %%
base_path = os.getcwd() # get the working direntory

path_images = os.path.join(base_path + "/data")
path_images
# Out:
# '/Users/cristinamulas/Desktop/deep_learning_project/data'

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
        validation_split=0.4)

train_generator = train_datagen.flow_from_directory(
        path_images,
        subset='training')

validation_generator = train_datagen.flow_from_directory(
        path_images, #same as in train generator
        subset='validation')
# Out:
# Found 73 images belonging to 4 classes.
# Found 47 images belonging to 4 classes.

# %%
os.listdir('/Users/cristinamulas/Desktop/deep_learning_project/data/test')
# Out:
# ['.DS_Store',
#  'water',
#  'chips',
#  'milk',
#  'wine',
#  'canfood',
#  '.ipynb_checkpoints',
#  'cookies']

# %%
## how many pics are in each class
os.listdir('/Users/cristinamulas/Desktop/deep_learning_project/data/train')
# Out:
# ['.DS_Store',
#  'water',
#  'chips',
#  'milk',
#  'wine',
#  'canfood',
#  '.ipynb_checkpoints',
#  'cookies']

# %%
train_generator = ImageDataGenerator(rescale=1./255,
                                     rotation_range=4,
                                   width_shift_range=0.1, 
                                   height_shift_range=0.1, 
                                   shear_range=0.3, 
                                   zoom_range=0.1, 
                                   horizontal_flip=False)
test_generator = ImageDataGenerator(rescale=1./255)

# %%
X_train_generator = train_generator.flow_from_directory(train_data_path, target_size=(32, 32), color_mode="rgb", batch_size = 32)
X_val_generator = test_generator.flow_from_directory(val_data_path, target_size=(32, 32), color_mode="rgb", )
X_test_generator = test_generator.flow_from_directory(test_data_path, target_size=(32, 32), color_mode="rgb",  batch_size =32)
# Out:
# Found 96 images belonging to 7 classes.
# Found 4 images belonging to 6 classes.
# Found 20 images belonging to 7 classes.

# %%
# def plot_class_imges()
# images = [ cv2.imread(os.path.join(folder,filename)) for filename in os.listdir(folder)]
# plt.figure(figsize=(20,10))
# columns = 4
# for i, image in enumerate(images):
#     plt.subplot(len(images) / columns + 1, columns, i + 1)
#     plt.imshow(image)

# %%
for cls in os.listdir('/Users/cristinamulas/Desktop/deep_learning_project/data/test'):
    if cls != '.DS_Store' and cls != '.ipynb_checkpoints':
        print(os.path.join(folder,cls))

images = []
for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        images.append(img)
images
i
plt.figure(figsize=(20,10))
columns = 4
for i, image in enumerate(images):
    plt.subplot(len(images) / columns + 1, columns, i + 1)
    plt.imshow(image)

# %%
images = os.listdir('/Users/cristinamulas/Desktop/deep_learning_project/data/test')

# %%
new = []
for cls in os.listdir('/Users/cristinamulas/Desktop/deep_learning_project/data/test'):
    if cls != '.DS_Store' and cls != '.ipynb_checkpoints':
        new.append(cls)
    for filename in 
new 
for i in
# Out:
# ['water', 'chips', 'milk', 'wine', 'canfood', 'cookies']

# %%
folder = "/Users/cristinamulas/Desktop/deep_learning_project/data/test/"
images_classes = []
for cls in os.listdir(folder):
    if cls != '.DS_Store' and cls != '.ipynb_checkpoints':
        images_classes.append(cls)
images_classes
# Out:
# ['water', 'chips', 'milk', 'wine', 'canfood', 'cookies']

# %%
for i in images_classes:
    new_images = []
    my_folder = os.path.join("/Users/cristinamulas/Desktop/deep_learning_project/data/test/",i)
    for file in os.listdir(os.path.join("/Users/cristinamulas/Desktop/deep_learning_project/data/test/",i)):
        if file != '.DS_Store' and file != '.ipynb_checkpoints':

            new_images.append(cv2.imread(os.path.join(my_folder,file)))
#     print(new_images)
    
    plt.figure(figsize=(20,10))
    columns = 10
    for i, image in enumerate(new_images):
        plt.subplot(len(new_images) / columns + 1, columns, i + 1)
        plt.imshow(image)

# %%
# Out:
# [array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 254, 255],
#          [255, 254, 255],
#          [255, 254, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 254, 255],
#          [255, 254, 255],
#          [255, 254, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 254, 255],
#          [255, 254, 255],
#          [255, 254, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [253, 255, 255],
#          [253, 255, 255],
#          [253, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [253, 255, 255],
#          [253, 255, 255],
#          [253, 255, 255]],
#
#         [[255, 255, 255],
# ...
